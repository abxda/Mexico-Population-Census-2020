# %%
import pandas as pd
import geopandas as gpd

# %%
estados = ["Aguascalientes","Baja California","Baja California Sur","Campeche","Coahuila de Zaragoza","Colima","Chiapas","Chihuahua","Ciudad de México","Durango","Guanajuato","Guerrero","Hidalgo","Jalisco","México","Michoacan de Ocampo","Morelos","Nayarit","Nuevo Leon","Oaxaca","Puebla","Queretaro","Quintana Roo","San Luis Potosi","Sinaloa","Sonora","Tabasco","Tamaulipas","tlaxcala","Veracruz Ignacio de la Llave","Yucatan","Zacatecas"]

# %%
rows = []
for i in range(32):
    print("Procesando: " + estados[i])
    df = pd.read_csv(f"./inegi/ccpvagebmza/csv/conjunto_de_datos/conjunto_de_datos_ageb_urbana_{estado}_cpv2020.csv",na_values=['N/A','N/D','*'])
    dfmza = df.drop(df[df.MZA == 0].index)
    manzanas_ccpv = dfmza.shape[0]
    mgmza = gpd.read_file(f"./inegi/mgccpv/gpkg/cpv2020_{estado}.gpkg")
    manzanas_mg = mgmza.shape[0]
    estado = str(i+1).zfill(2)    
    rows.append([estados[i], estado,manzanas_ccpv,manzanas_mg,manzanas_ccpv - manzanas_mg ])

comparacion = pd.DataFrame(rows, columns=["Estado", "CVE_EDO", "Total_Manzanas_CCPV", "Total_Manzanas_MG", "Diferencia"])

# %%
comparacion
# Out:
#                           Estado CVE_EDO  Total_Manzanas_CCPV  \
# 0                 Aguascalientes      01               128626
# 1                Baja California      02                14367
# 2            Baja California Sur      03                51463
# 3                       Campeche      04                15157
# 4           Coahuila de Zaragoza      05                10570
# 5                         Colima      06                50637
# 6                        Chiapas      07                12470
# 7                      Chihuahua      08                48685
# 8               Ciudad de México      09                65049
# 9                        Durango      10                63181
# 10                    Guanajuato      11                29267
# 11                      Guerrero      12                59357
# 12                       Hidalgo      13                51679
# 13                       Jalisco      14                35126
# 14                        México      15                92493
# 15           Michoacan de Ocampo      16               128626
# 16                       Morelos      17                61767
# 17                       Nayarit      18                26500
# 18                    Nuevo Leon      19                18262
# 19                        Oaxaca      20                65582
# 20                        Puebla      21                43930
# 21                     Queretaro      22                63469
# 22                  Quintana Roo      23                26549
# 23               San Luis Potosi      24                22620
# 24                       Sinaloa      25                33454
# 25                        Sonora      26                41481
# 26                       Tabasco      27                57254
# 27                    Tamaulipas      28                15480
# 28                      tlaxcala      29                56561
# 29  Veracruz Ignacio de la Llave      30                15268
# 30                       Yucatan      31                85583
# 31                     Zacatecas      32                33849
#
#     Total_Manzanas_MG  Diferencia
# 0              128626           0
# 1               14367           0
# 2               51463           0
# 3               15157           0
# 4               10570           0
# 5               50637           0
# 6               12470           0
# 7               48685           0
# 8               65049           0
# 9               63181           0
# 10              29267           0
# 11              59357           0
# 12              51679           0
# 13              35126           0
# 14              92493           0
# 15             128626           0
# 16              61767           0
# 17              26500           0
# 18              18262           0
# 19              65582           0
# 20              43930           0
# 21              63469           0
# 22              26549           0
# 23              22620           0
# 24              33454           0
# 25              41481           0
# 26              57254           0
# 27              15480           0
# 28              56561           0
# 29              15268           0
# 30              85583           0
# 31              33849           0
